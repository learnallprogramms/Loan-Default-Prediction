# %%
# Import necessary libraries
import numpy as np  # For numerical operations
import pandas as pd  # For data manipulation and analysis
import matplotlib.pyplot as plt  # For data visualization
import seaborn as sns  # For enhanced data visualization

# Suppress warnings
import warnings  # For managing warnings in the code
warnings.filterwarnings('ignore')  # Ignore all warnings

# %%
# Read the CSV file into a pandas DataFrame
df2 = pd.read_csv('Data_without_Scaling_&_without_Outliers_Treatment.csv')

# Display the first few rows of the DataFrame to inspect the data
df2.head()
# Out:
#    V2  V3    V4   V5      V6       V7    V8      V9 V10  V11  ...   V17 V18  \
# 0   0   0  24.0  0.0  2432.0  46500.0  24.0  1385.0  SC  0.0  ...  40.0   1
# 1   0   1  24.0  1.0  1495.0  28168.0  24.0  2496.0  MO  0.0  ...  47.0   1
# 2   0   0  26.0  0.0  1707.0  38900.0  30.0  1346.0  SC  0.0  ...  31.0   9
# 3   0   0  24.0  0.0  2128.0  42900.0  24.0  1375.0  SC  2.0  ...  24.0   1
# 4   0   0  27.0  0.0  1824.0  40900.0  30.0  4140.0  MC  0.0  ...  30.0   1
#
#   V19 V20      V25  V28  V29  V30     V31  V32
# 0   1   0  46500.0    0    0    0  TIER 1    0
# 1   1   0  28168.0    0    0    0  TIER 1    0
# 2   6   3  38900.0   31   31   16  TIER 1    0
# 3   1   0  42900.0    0    0    0  TIER 1    0
# 4   1   0  40900.0    0    0    0  TIER 1    0
#
# [5 rows x 24 columns]

# %% [markdown]
# # Hypothesis Testing for Numerical Columns

# %% [raw]
# Case 1: Normality and Equal Variances
# If the data is normally distributed and variances are equal, use parametric tests:
#
# t-test (for comparing means between two groups)
# ANOVA (for comparing means among three or more groups)
#
# Case 2: Normality and Unequal Variances
# If the data is normally distributed but variances are unequal, use:
#
# Welch's t-test (for comparing means between two groups with unequal variances)
# Welch's ANOVA (for comparing means among three or more groups with unequal variances)
#
# Case 3: Non-Normality
# If the data is not normally distributed, use non-parametric tests:
#
# Mann-Whitney U test (for comparing two independent groups)
# Kruskal-Wallis H test (for comparing three or more independent groups)

# %%
from scipy.stats import shapiro, levene, mannwhitneyu

# Perform the sampling
x = df2[df2['V32'] == 1]['V6'].sample(n=1500, random_state=1).reset_index(drop=True)
y = df2[df2['V32'] == 0]['V6'].sample(n=1500, random_state=1).reset_index(drop=True)

# Normality check for x
test_stats, p_value_x = shapiro(x)
print('p_value for x :', p_value_x)
if p_value_x <= 0.05:
    print('Data is Not Normal')
else:
    print('Data is Normal')

print()

# Normality check for y
test_stats, p_value_y = shapiro(y)
print('p_value for y :', p_value_y)
if p_value_y <= 0.05:
    print('Data is Not Normal')
else:
    print('Data is Normal')

print()

# Variance check
test_stats, p_value_var = levene(x, y)
print('variances p_value :', p_value_var)
if p_value_var <= 0.05:
    print('Variances are Not Equal')
else:
    print('Variances are Equal')

print()

# Mann-Whitney U test (non-parametric, two groups)
u_stat, p_value_mw = mannwhitneyu(x, y)
print('whitney score :', round(u_stat, 2))
print('P_value for whitney :', round(p_value_mw, 6))

# Step 4: Decision rule based on alpha (significance level)
alpha = 0.05
if p_value_mw < alpha:
    decision = 'Significant'  # Feature is significant
else:
    decision = 'Not Significant'  # Feature might not be significant

# Step 5: Draw the conclusion
conclusion = f"U statistic: {u_stat}, p-value: {p_value_mw}, Decision: {decision}"
print(conclusion)
# Out:
# p_value for x : 3.048848834946993e-12
# Data is Not Normal
#
# p_value for y : 4.1060079669207116e-14
# Data is Not Normal
#
# variances p_value : 0.9887703859777298
# Variances are Equal
#
# whitney score : 1152088.5
# P_value for whitney : 0.253478
# U statistic: 1152088.5, p-value: 0.2534781188487364, Decision: Not Significant

# %%
# Perform the sampling
x = df2[df2['V32'] == 1]['V7'].sample(n=1500, random_state=1).reset_index(drop=True)
y = df2[df2['V32'] == 0]['V7'].sample(n=1500, random_state=1).reset_index(drop=True)

# Normality check for x
test_stats, p_value_x = shapiro(x)
print('p_value for x :', p_value_x)
if p_value_x <= 0.05:
    print('Data is Not Normal')
else:
    print('Data is Normal')

print()

# Normality check for y
test_stats, p_value_y = shapiro(y)
print('p_value for y :', p_value_y)
if p_value_y <= 0.05:
    print('Data is Not Normal')
else:
    print('Data is Normal')

print()

# Variance check
test_stats, p_value_var = levene(x, y)
print('variances p_value :', p_value_var)
if p_value_var <= 0.05:
    print('Variances are Not Equal')
else:
    print('Variances are Equal')

print()

# Mann-Whitney U test (non-parametric, two groups)
u_stat, p_value_mw = mannwhitneyu(x, y)
print('whitney score :', round(u_stat, 2))
print('P_value for whitney :', round(p_value_mw, 6))

# Step 4: Decision rule based on alpha (significance level)
alpha = 0.05
if p_value_mw < alpha:
    decision = 'Significant'  # Feature is significant
else:
    decision = 'Not Significant'  # Feature might not be significant

# Step 5: Draw the conclusion
conclusion = f"U statistic: {u_stat}, p-value: {p_value_mw}, Decision: {decision}"
print(conclusion)
# Out:
# p_value for x : 7.165917033600397e-14
# Data is Not Normal
#
# p_value for y : 3.2807422010911762e-15
# Data is Not Normal
#
# variances p_value : 0.812333819588763
# Variances are Equal
#
# whitney score : 1197485.5
# P_value for whitney : 0.002244
# U statistic: 1197485.5, p-value: 0.0022444949966714685, Decision: Significant

# %%
# Perform the sampling
x = df2[df2['V32'] == 1]['V9'].sample(n=1500, random_state=1).reset_index(drop=True)
y = df2[df2['V32'] == 0]['V9'].sample(n=1500, random_state=1).reset_index(drop=True)

# Normality check for x
test_stats, p_value_x = shapiro(x)
print('p_value for x :', p_value_x)
if p_value_x <= 0.05:
    print('Data is Not Normal')
else:
    print('Data is Normal')

print()

# Normality check for y
test_stats, p_value_y = shapiro(y)
print('p_value for y :', p_value_y)
if p_value_y <= 0.05:
    print('Data is Not Normal')
else:
    print('Data is Normal')

print()

# Variance check
test_stats, p_value_var = levene(x, y)
print('variances p_value :', p_value_var)
if p_value_var <= 0.05:
    print('Variances are Not Equal')
else:
    print('Variances are Equal')

print()

# Mann-Whitney U test (non-parametric, two groups)
u_stat, p_value_mw = mannwhitneyu(x, y)
print('whitney score :', round(u_stat, 2))
print('P_value for whitney :', round(p_value_mw, 6))

# Step 4: Decision rule based on alpha (significance level)
alpha = 0.05
if p_value_mw < alpha:
    decision = 'Significant'  # Feature is significant
else:
    decision = 'Not Significant'  # Feature might not be significant

# Step 5: Draw the conclusion
conclusion = f"U statistic: {u_stat}, p-value: {p_value_mw}, Decision: {decision}"
print(conclusion)
# Out:
# p_value for x : 1.3074071375639623e-51
# Data is Not Normal
#
# p_value for y : 3.59024649927407e-50
# Data is Not Normal
#
# variances p_value : 0.6406000386330254
# Variances are Equal
#
# whitney score : 1197244.5
# P_value for whitney : 0.002322
# U statistic: 1197244.5, p-value: 0.0023223808522652967, Decision: Significant

# %%
# Perform the sampling
x = df2[df2['V32'] == 1]['V17'].sample(n=1500, random_state=1).reset_index(drop=True)
y = df2[df2['V32'] == 0]['V17'].sample(n=1500, random_state=1).reset_index(drop=True)

# Normality check for x
test_stats, p_value_x = shapiro(x)
print('p_value for x :', p_value_x)
if p_value_x <= 0.05:
    print('Data is Not Normal')
else:
    print('Data is Normal')

print()

# Normality check for y
test_stats, p_value_y = shapiro(y)
print('p_value for y :', p_value_y)
if p_value_y <= 0.05:
    print('Data is Not Normal')
else:
    print('Data is Normal')

print()

# Variance check
test_stats, p_value_var = levene(x, y)
print('variances p_value :', p_value_var)
if p_value_var <= 0.05:
    print('Variances are Not Equal')
else:
    print('Variances are Equal')

print()

# Mann-Whitney U test (non-parametric, two groups)
u_stat, p_value_mw = mannwhitneyu(x, y)
print('whitney score :', round(u_stat, 2))
print('P_value for whitney :', round(p_value_mw, 6))

# Step 4: Decision rule based on alpha (significance level)
alpha = 0.05
if p_value_mw < alpha:
    decision = 'Significant'  # Feature is significant
else:
    decision = 'Not Significant'  # Feature might not be significant

# Step 5: Draw the conclusion
conclusion = f"U statistic: {u_stat}, p-value: {p_value_mw}, Decision: {decision}"
print(conclusion)
# Out:
# p_value for x : 1.9851163918170368e-20
# Data is Not Normal
#
# p_value for y : 1.7728923143649174e-17
# Data is Not Normal
#
# variances p_value : 9.032667632302845e-05
# Variances are Not Equal
#
# whitney score : 944492.0
# P_value for whitney : 0.0
# U statistic: 944492.0, p-value: 2.6724506824859315e-14, Decision: Significant

# %%
# Perform the sampling
x = df2[df2['V32'] == 1]['V25'].sample(n=1500, random_state=1).reset_index(drop=True)
y = df2[df2['V32'] == 0]['V25'].sample(n=1500, random_state=1).reset_index(drop=True)

# Normality check for x
test_stats, p_value_x = shapiro(x)
print('p_value for x :', p_value_x)
if p_value_x <= 0.05:
    print('Data is Not Normal')
else:
    print('Data is Normal')

print()

# Normality check for y
test_stats, p_value_y = shapiro(y)
print('p_value for y :', p_value_y)
if p_value_y <= 0.05:
    print('Data is Not Normal')
else:
    print('Data is Normal')

print()

# Variance check
test_stats, p_value_var = levene(x, y)
print('variances p_value :', p_value_var)
if p_value_var <= 0.05:
    print('Variances are Not Equal')
else:
    print('Variances are Equal')

print()

# Mann-Whitney U test (non-parametric, two groups)
u_stat, p_value_mw = mannwhitneyu(x, y)
print('whitney score :', round(u_stat, 2))
print('P_value for whitney :', round(p_value_mw, 6))

# Step 4: Decision rule based on alpha (significance level)
alpha = 0.05
if p_value_mw < alpha:
    decision = 'Significant'  # Feature is significant
else:
    decision = 'Not Significant'  # Feature might not be significant

# Step 5: Draw the conclusion
conclusion = f"U statistic: {u_stat}, p-value: {p_value_mw}, Decision: {decision}"
print(conclusion)
# Out:
# p_value for x : 8.154542402614868e-54
# Data is Not Normal
#
# p_value for y : 7.328173532579983e-30
# Data is Not Normal
#
# variances p_value : 0.8370549367014897
# Variances are Equal
#
# whitney score : 1188133.0
# P_value for whitney : 0.00773
# U statistic: 1188133.0, p-value: 0.007729877627347954, Decision: Significant

# %% [markdown]
# # Hypothesis Testing for categorical Columns

# %%
from scipy.stats import chi2_contingency

# %%
# Create a contingency table
contingency_table = pd.crosstab(df2.V10, df2.V32)

# Perform Chi-Square test
chi2_stat, p_value_ch, dof, ex = chi2_contingency(contingency_table)

print(f"Chi-Square Statistic: {chi2_stat}")
print(f"P-Value: {p_value_ch}")
print()

# Step 4: Decision rule based on alpha (significance level)
alpha = 0.05
if p_value_ch < alpha:
    decision = 'Significant'  # Feature is significant
else:
    decision = 'Not Significant'  # Feature might not be significant

# Step 5: Draw the conclusion
conclusion = f"Chi2 statistic: {chi2_stat}, p-value: {p_value_ch}, Decision: {decision}"
print(conclusion)
# Out:
# Chi-Square Statistic: 83.17580067050977
# P-Value: 3.697350303396039e-17
#
# Chi2 statistic: 83.17580067050977, p-value: 3.697350303396039e-17, Decision: Significant

# %%
# Create a contingency table
contingency_table = pd.crosstab(df2.V13, df2.V32)

# Perform Chi-Square test
chi2_stat, p_value_ch, dof, ex = chi2_contingency(contingency_table)

print(f"Chi-Square Statistic: {chi2_stat}")
print(f"P-Value: {p_value_ch}")
print()

# Step 4: Decision rule based on alpha (significance level)
alpha = 0.05
if p_value_ch < alpha:
    decision = 'Significant'  # Feature is significant
else:
    decision = 'Not Significant'  # Feature might not be significant

# Step 5: Draw the conclusion
conclusion = f"Chi2 statistic: {chi2_stat}, p-value: {p_value_ch}, Decision: {decision}"
print(conclusion)
# Out:
# Chi-Square Statistic: 19.330703086654783
# P-Value: 1.0992450341335042e-05
#
# Chi2 statistic: 19.330703086654783, p-value: 1.0992450341335042e-05, Decision: Significant

# %%
# Create a contingency table
contingency_table = pd.crosstab(df2.V14, df2.V32)

# Perform Chi-Square test
chi2_stat, p_value_ch, dof, ex = chi2_contingency(contingency_table)

print(f"Chi-Square Statistic: {chi2_stat}")
print(f"P-Value: {p_value_ch}")
print()

# Step 4: Decision rule based on alpha (significance level)
alpha = 0.05
if p_value_ch < alpha:
    decision = 'Significant'  # Feature is significant
else:
    decision = 'Not Significant'  # Feature might not be significant

# Step 5: Draw the conclusion
conclusion = f"Chi2 statistic: {chi2_stat}, p-value: {p_value_ch}, Decision: {decision}"
print(conclusion)
# Out:
# Chi-Square Statistic: 41.59573037347804
# P-Value: 2.0230931346180932e-08
#
# Chi2 statistic: 41.59573037347804, p-value: 2.0230931346180932e-08, Decision: Significant

# %%
# Create a contingency table
contingency_table = pd.crosstab(df2.V15, df2.V32)

# Perform Chi-Square test
chi2_stat, p_value_ch, dof, ex = chi2_contingency(contingency_table)

print(f"Chi-Square Statistic: {chi2_stat}")
print(f"P-Value: {p_value_ch}")
print()

# Step 4: Decision rule based on alpha (significance level)
alpha = 0.05
if p_value_ch < alpha:
    decision = 'Significant'  # Feature is significant
else:
    decision = 'Not Significant'  # Feature might not be significant

# Step 5: Draw the conclusion
conclusion = f"Chi2 statistic: {chi2_stat}, p-value: {p_value_ch}, Decision: {decision}"
print(conclusion)
# Out:
# Chi-Square Statistic: 4.71388911270546
# P-Value: 0.09470916005780379
#
# Chi2 statistic: 4.71388911270546, p-value: 0.09470916005780379, Decision: Not Significant

# %%
# Create a contingency table
contingency_table = pd.crosstab(df2.V31, df2.V32)

# Perform Chi-Square test
chi2_stat, p_value_ch, dof, ex = chi2_contingency(contingency_table)

print(f"Chi-Square Statistic: {chi2_stat}")
print(f"P-Value: {p_value_ch}")
print()

# Step 4: Decision rule based on alpha (significance level)
alpha = 0.05
if p_value_ch < alpha:
    decision = 'Significant'  # Feature is significant
else:
    decision = 'Not Significant'  # Feature might not be significant

# Step 5: Draw the conclusion
conclusion = f"Chi2 statistic: {chi2_stat}, p-value: {p_value_ch}, Decision: {decision}"
print(conclusion)
# Out:
# Chi-Square Statistic: 209.24681328156237
# P-Value: 4.2360603759388514e-45
#
# Chi2 statistic: 209.24681328156237, p-value: 4.2360603759388514e-45, Decision: Significant
